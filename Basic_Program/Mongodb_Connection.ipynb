# %%
import pymongo
from pymongo import MongoClient
import json
import twitter
from pprint import pprint
CONSUMER_KEY="JaUV2OJICyCeTmNHSl0hknTAc"
CONSUMER_SECRET="-------------------------------------"
OAUTH_TOKEN="*****************************************************"
OAUTH_TOKEN_SECRET="++++++++++++++++++++++++++++++++++++++++++++++++"            
auth=twitter.oauth.OAuth(OAUTH_TOKEN,OAUTH_TOKEN_SECRET,CONSUMER_KEY,CONSUMER_SECRET)
twitter_api=twitter.Twitter(auth=auth)
client=MongoClient()
db=client.tweet_db
tweet_collection=db.tweet_collection
tweet_collection.create_index([("id",pymongo.ASCENDING)],unique=True)
count=50
q="salesforce"
search_results=twitter_api.search.tweets(count=count,q=q)
#pprint(search_results['search_metadata'])


statuses=search_results["statuses"]

since_id_new=statuses[-1]['id']

for statues in statuses:
       try:
              tweet_collection.insert(statues)
       except:
              pass
tweet_cursor=tweet_collection.find()
print(tweet_cursor.count())
user_cursor=tweet_collection.distinct("user.id")
print(len(user_cursor))

for document in tweet_cursor:
       try:
              print('-----')
              print('name:-',document["user"]["name"])
              print('text:-',document["text"])
              print('Created Date:-',document["created_at"])
       except:
              print("Error in Encoding")
              pass
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
# 150
# 126
# -----
# name:- Jyoti agarwal
# text:- @ITConsultants4u @Contest_in @Contest_Hub @ITcontest @ITContest2013 @ContestsInIndia @Contestmumbai @ContestIndiaa… https://t.co/ewBreK19TB
# Created Date:- Fri Feb 07 11:26:51 +0000 2020
# -----
# name:- DEEPAK VATS
# text:- RT @chilled_Sup: @ITConsultants4u @Contest_in @Contest_Hub @ITcontest @ITContest2013 @ContestsInIndia @Contestmumbai @ContestIndiaa @_conte…
# Created Date:- Fri Feb 07 11:30:33 +0000 2020
# -----
# name:- Agent
# text:- RT @cryptohodler16: Here we go😊
#
# What I've long suspected-- Japan being prepped as the US bridge to the East.
#
# I'll eat my socks if SBI, So…
# Created Date:- Fri Feb 07 11:28:49 +0000 2020
# -----
# name:- hana@マーケ | RECEPTIONIST
# text:- RECEPTIONISTが、Salesforceと連携できるようになりました！！😊
# Salesforce × RECEPTIONISTユーザーの皆さんはぜひ使ってみてください〜！！ https://t.co/et8YZtSHL6
# Created Date:- Fri Feb 07 11:28:25 +0000 2020
# -----
# name:- sfdcbot 🤖
# text:- RT @ThisIsRSN: Just earned the Dispatcher Console for Admins badge on @Trailhead and you should too!
# #30minsOnTrailhead #trailhead #salesf…
# Created Date:- Fri Feb 07 11:27:40 +0000 2020
# -----
# name:- Sticker Mule
# text:- @teamtrihouse @nicoletabak @salesforce @Wendys https://t.co/XJJOrCEAfh
# Created Date:- Fri Feb 07 11:27:12 +0000 2020
# -----
# name:- Ｔｏｎｙ Ｓｍｉｔｈ ＡＣＩＨ                     #SocialHousing
# text:- RT @HousingITguy: In #SocialHousing,is ERP becoming the new HMS🤔
#
# Is SalesForce to change the #ukHousing game. A horse coming up on the ins…
# Created Date:- Fri Feb 07 11:26:44 +0000 2020
# -----
# name:- Ｔｏｎｙ Ｓｍｉｔｈ ＡＣＩＨ                     #SocialHousing
# text:- RT @HousingITguy: In #SocialHousing,is ERP becoming the new HMS🤔
#
# Is SalesForce to change the #ukHousing game. A horse coming up on the ins…
# Created Date:- Fri Feb 07 11:26:26 +0000 2020
# -----
# name:- Ｔｏｎｙ Ｓｍｉｔｈ ＡＣＩＨ                     #SocialHousing
# text:- RT @HousingITguy: In #SocialHousing,is ERP becoming the new HMS🤔
#
# Is SalesForce to change the #ukHousing game. A horse coming up on the ins…
# Created Date:- Fri Feb 07 11:26:10 +0000 2020
# -----
# name:- Matthieu Bodin
# text:- @nicoletabak @salesforce @todoist has always been awesome and quick to help ✅
# Created Date:- Fri Feb 07 11:25:56 +0000 2020
# -----
# name:- Himanshu Rijhwani
# text:- RT @Smiley_Bharati: @ITConsultants4u @Contest_in @Contest_Hub @ITcontest @ITContest2013 @ContestsInIndia @Contestmumbai @ContestIndiaa @_co…
# Created Date:- Fri Feb 07 11:25:50 +0000 2020
# -----
# name:- Vaishali
# text:- RT @khemka_nidhi: @ITConsultants4u @Contest_in @Contest_Hub @ITcontest @ITContest2013 @ContestsInIndia @Contestmumbai @ContestIndiaa @_cont…
# Created Date:- Fri Feb 07 11:25:00 +0000 2020
# -----
# name:- India Taylor Owens
# text:- @salesforce Thanks for taking my very important message
# Created Date:- Fri Feb 07 11:24:52 +0000 2020
# -----
# name:- sfdcbot 🤖
# text:- RT @shubham_sfdc: What a Lovely Surprise from @salesforce.
#
# Thank you so much for the love and support.
#
# Thank you @Bhanz19 Ma'am for the l…
# Created Date:- Fri Feb 07 11:24:31 +0000 2020
# -----
# name:- Shubham Bhardwaj 🐻
# text:- What a Lovely Surprise from @salesforce.
#
# Thank you so much for the love and support.
#
# Thank you @Bhanz19 Ma'am for… https://t.co/Snd5b8p5lt
# Created Date:- Fri Feb 07 11:24:26 +0000 2020
# -----
# name:- Astound Commerce UK
# text:- Proud to announce we’ve been nominated as a finalist in the #Yotpo 2020 Partner Awards for Best @salesforce… https://t.co/JoiEMCFHQX
# Created Date:- Fri Feb 07 11:24:09 +0000 2020
# -----
# name:- Iko Kazi
# text:- RT @campusbizKE: Salesforce Administrator | Bidhaa Sasa | Nairobi | Min. 1yr SalesForce exp. | Sal. 60k
#
# Details &gt;: https://t.co/AtlPllGyy…
# Created Date:- Fri Feb 07 11:23:37 +0000 2020
# -----
# name:- #IkoKaziKE Influencer
# text:- Salesforce Administrator | Bidhaa Sasa | Nairobi | Min. 1yr SalesForce exp. | Sal. 60k
#
# Details &gt;:… https://t.co/Nqmnexr9Jk
# Created Date:- Fri Feb 07 11:23:31 +0000 2020
# -----
# name:- Reshu Tomar
# text:- @cDavidSmith2403 @karunatayal03 @salesforce @trailhead @Sales Congratulations🎉🎊
# Created Date:- Fri Feb 07 11:22:31 +0000 2020
# -----
# name:- Charlotte Ashton
# text:- 🎉😃🎉An awesome Einstein Analytics badge on @Trailhead to get to me 200 badges  🎉😃🎉https://t.co/3lmHZRRviZ
# Created Date:- Fri Feb 07 11:22:14 +0000 2020
# -----
# name:- Stephan Baasch
# text:- RT @BlakeMichelleM: The Company Of The Future Has A Soul - new @ForbesCMO post and YouTube video @Benioff @salesforce @nytimes https://t.co…
# Created Date:- Fri Feb 07 11:21:22 +0000 2020
# -----
# name:- netzpalaver
# text:- RT @netzpalaver: Apple, Adobe, Salesforce, Google und Microsoft gehören zu den Top-Akquisiteuren von Enterprise-Software
#
# Aktueller Report…
# Created Date:- Fri Feb 07 11:20:54 +0000 2020
# -----
# name:- Gopalakrishnan P
# text:- @ITConsultants4u @Contest_in @Contest_Hub @ITcontest @ITContest2013 @ContestsInIndia @Contestmumbai @ContestIndiaa… https://t.co/GChgJYBamC
# Created Date:- Fri Feb 07 11:20:49 +0000 2020
# -----
# name:- Marco Giovanni Sain
# text:- @salesforce Yeah
# Created Date:- Fri Feb 07 11:20:45 +0000 2020
# -----
# name:- netzpalaver
# text:- RT @netzpalaver: #Apple, #Adobe, #Salesforce, #Google und #Microsoft gehören zu den Top-Akquisiteuren von #EnterpriseSoftware
#
# #Akquisitio…
# Created Date:- Fri Feb 07 11:20:43 +0000 2020
# -----
# name:- Bivett
# text:- BOLDFORCE VCS: Leveraging Capital &amp; Building Black Wealth 🙌🏾🖤💕💚🌱📈 #investing #blackhistorymonth #blacksintech… https://t.co/aYzUi1EcFQ
# Created Date:- Fri Feb 07 11:20:02 +0000 2020
# -----
# name:- Leadclic Solutions
# text:- ¿Porqué @Genesys y no otro? Te contamos (casi) todo sobre la gran plataforma de #CallCenter: #GenesysCloud, con la… https://t.co/bmZQE4wuPt
# Created Date:- Fri Feb 07 11:18:33 +0000 2020
# -----
# name:- EmorphisTechnologies
# text:- Learn how to integrate Salesforce with our Ultimate Salesforce Integration Guide to improve collaboration and accel… https://t.co/9pM2tTZEuA
# Created Date:- Fri Feb 07 11:17:31 +0000 2020
# -----
# name:- Stuart Hamilton
# text:- RT @karenfidelak: If you develop, build or release on Salesforce, I'd love your input to help inform our product plans. I plan to run a ser…
# Created Date:- Fri Feb 07 11:16:33 +0000 2020
# -----
# name:- Technojobs Limited
# text:- Salesforce Account Executive - £95k + OTE - London https://t.co/LdvcRG9k9b #.netjobs
# Created Date:- Fri Feb 07 11:16:32 +0000 2020
# -----
# name:- Mayur Shingote
# text:- RT @it_numeric: L’App Marketplace de Zoom compte plus de 200 applications et intégrations natives venant des meilleures technologies dispon…
# Created Date:- Fri Feb 07 11:16:28 +0000 2020
# -----
# name:- sfdcbot 🤖
# text:- RT @technofactr: #Automation #Testers read this: Updating UI Tests for the #Spring20 App Launcher - #Salesforce Developers Blog https://t.c…
# Created Date:- Fri Feb 07 11:15:15 +0000 2020
# -----
# name:- Kelly Singsank
# text:- Turn Your Mobile Workers into Connected Field Service Agents https://t.co/aJJBCntnt1 via @salesforce
# Created Date:- Fri Feb 07 11:15:12 +0000 2020
# -----
# name:- AV
# text:- #Automation #Testers read this: Updating UI Tests for the #Spring20 App Launcher - #Salesforce Developers Blog… https://t.co/qhKUTD36CW
# Created Date:- Fri Feb 07 11:15:10 +0000 2020
# -----
# name:- Zachary Jeans
# text:- RT @gabbalishus: Don’t forget to wear RED for Congenital Heart Defect tomorrow and post a picture. Let’s show our support for everyone who…
# Created Date:- Fri Feb 07 11:13:24 +0000 2020
# -----
# name:- ☁️ Claire Jones ☁️
# text:- RT @LondonSFDCWIT: Here is the link to the kids coding event at Salesforce Tower tomorrow. A great opportunity to get your youngsters inter…
# Created Date:- Fri Feb 07 11:13:19 +0000 2020
# -----
# name:- Salesforce DG Tokyo
# text:- [Qiita] Salesforceタグが付けられた新着投稿 #sfdg - lightning web component ：コンポーネント間リレーションとイベント通知 https://t.co/huSs1x67Ry
# Created Date:- Fri Feb 07 11:12:15 +0000 2020
# -----
# name:- Doteveryone
# text:- Consequence Scanning is an agile practice that's being adopted by organisations like @salesforce, right now!
#
# Ligh… https://t.co/jtaqCAU3r2
# Created Date:- Fri Feb 07 11:11:53 +0000 2020
# -----
# name:- 益田太貴｜PR/Marketing Director
# text:- SalesForceと連携！
#
# RECEPTIONIST_WEBがアップデートされて、受付コードを発行する時に、SalesForceから取引先の情報を自動で反映されるようになりました！少し楽に。笑
#
# 何卒。。。。 https://t.co/L9ubhcqQXm
# Created Date:- Fri Feb 07 11:11:07 +0000 2020
# -----
# name:- Foster Care Today
# text:- RT @JenniferCurran1: Join Salesforce and Accenture for our webinar about making tech work for child welfare on March 5, 2020 at 2PM EST. ht…
# Created Date:- Fri Feb 07 11:10:46 +0000 2020
# -----
# name:- ☁️ Tom Blamire ☁️
# text:- What’s the Best Way to Implement a CRM for Nonprofits?
# https://t.co/E8NyN1hB0j
# Created Date:- Fri Feb 07 11:10:07 +0000 2020
# -----
# name:- guai3s
# text:- RT @receptionistJP: 【アップデートのお知らせ】
#
# SalesforceとRECEPTIONISTの連携が行えるようになりました。
#
# アポイントメントの来訪者情報に、Salesforceの取引先責任者情報を取得することができます。
#
# Salesforceを利用…
# Created Date:- Fri Feb 07 11:09:29 +0000 2020
# -----
# name:- Salesforce DG Tokyo
# text:- [はてなブックマーク] 本文「Salesforce」を検索 #sfdg - まつもとゆきひろさんと、なかだのぶよしさんと、Rubyについてのお話 - ポッドキャスト | Heroku https://t.co/GKLhgPBKXs
# Created Date:- Fri Feb 07 11:08:09 +0000 2020
# -----
# name:- ⚡️ EVE DI PALMA ⚡️
# text:- RT @luzyne_fr: #SalesForce Réunion / work shop des équipes commerciales de l'Uzyne, de @Quadriplay et Com'Unique. #Sport #Shopper #MediaTac…
# Created Date:- Fri Feb 07 11:07:34 +0000 2020
# -----
# name:- Clare Herbert
# text:- @chrisEmmett @salesforce Ha ha I do this all the time.
# Created Date:- Fri Feb 07 11:07:18 +0000 2020
# -----
# name:- RECEPTIONIST(クラウド受付システム)公式
# text:- 【アップデートのお知らせ】
#
# SalesforceとRECEPTIONISTの連携が行えるようになりました。
#
# アポイントメントの来訪者情報に、Salesforceの取引先責任者情報を取得することができます。
#
# Salesforc… https://t.co/OOAwnmZUte
# Created Date:- Fri Feb 07 11:07:00 +0000 2020
# -----
# name:- Georg Blum
# text:- Auch #Microsoft könnte neben #Google an #Salesforce interessiert sein.
#
# schaut #Oracle nur zu?
#
# Ich denke #SAP wi… https://t.co/P5ahhPEzZN
# Created Date:- Fri Feb 07 11:05:09 +0000 2020
# -----
# name:- 🇮🇳 Aarav Singh 🇮🇳
# text:- RT @Smiley_Bharati: @ITConsultants4u @Contest_in @Contest_Hub @ITcontest @ITContest2013 @ContestsInIndia @Contestmumbai @ContestIndiaa @_co…
# Created Date:- Fri Feb 07 11:04:28 +0000 2020
# -----
# name:- Mike Reynolds
# text:- @Kalapilakal @salesforce @trailhead Very nice!
# Created Date:- Fri Feb 07 11:04:16 +0000 2020
# -----
# name:- Salesforce Germany
# text:- Kunden informieren sich immer mehr in sozialen Netzwerken. Hier bietet sich für den #Mittelstand eine große Chance:… https://t.co/DlcHaAWiWO
# Created Date:- Fri Feb 07 11:04:03 +0000 2020
# -----
# name:- Srini Vasan
# text:- RT @SalemRRajendran: இந்தியாவை மதரீதியாகப் பிளவுபடுத்தும் #CAA_NRC_NPR எதிராக சேலம் மத்திய மாவட்ட தி.மு.க சார்பிலான மதச்சார்பற்ற முற்போக்கு…
# Created Date:- Fri Feb 07 11:38:47 +0000 2020
# -----
# name:- PRAVEENKUMAR.R
# text:- RT @AvadiNazar: கழக தலைவர் வணக்கத்திற்குரிய @mkstalin அவர்களின் வழியில் இன்று ஆவடியில் திருமண மணமக்களை வாழ்த்தியதுடன், #CAA_NRC_NPR ஆகியவற்…
# Created Date:- Fri Feb 07 11:38:47 +0000 2020
# -----
# name:- Mohammad Akbar Ashrafi
# text:- RT @kanhaiyakumar: आज जन-गण-मन यात्रा के आठवें दिन सहरसा और मधेपुरा में जन-सभाओं का आयोजन हुआ। अच्छे दिन का झाँसा देकर सत्ता में आने वालों…
# Created Date:- Fri Feb 07 11:38:44 +0000 2020
# -----
# name:- PRAVEENKUMAR.R
# text:- RT @arivalayam: ”பாஜக மற்றும் அதிமுக அரசுகள் மக்களுக்கு செய்துள்ள துரோகத்தை வெளிப்படுத்தவும் – #CAA_NRC_NPR ஆகியவற்றை திரும்பப்பெற வலியுறு…
# Created Date:- Fri Feb 07 11:38:41 +0000 2020
# -----
# name:- One Man army
# text:- @cloudno07 @davechers @palakkadan @naukarshah @PanickarS People here are protesting against NRC +CAA. Not alone eit… https://t.co/EihCfDKt0H
# Created Date:- Fri Feb 07 11:38:36 +0000 2020
# -----
# name:- ~Tasha~ نتاشا
# text:- RT @seemay: To a call from the Rector at Deoband's Dar ul Uloom, to put the protest on hold, a protestor, Shabana Qureshi reacts: "it is no…
# Created Date:- Fri Feb 07 11:38:34 +0000 2020
# -----
# name:- Navneet Yadav
# text:- RT @kanhaiyakumar: आज जन-गण-मन यात्रा के आठवें दिन सहरसा और मधेपुरा में जन-सभाओं का आयोजन हुआ। अच्छे दिन का झाँसा देकर सत्ता में आने वालों…
# Created Date:- Fri Feb 07 11:38:29 +0000 2020
# -----
# name:- 🆁🅰🅹🅽🅴🅴🆂🅷 🅺🆄🅼🅰🆁
# text:- RT @Narendra_kc_: किसी के बाप का हिंदुस्तान थोड़ी है: राहत इंदौरी ने दी नसीहत
#
# उन्हें किसी शिक्षित व्यक्ति से देश का संविधान पढ़वाकर समझने…
# Created Date:- Fri Feb 07 11:38:26 +0000 2020
# -----
# name:- Zara Raj Parwal
# text:- RT @MyFellowIndians: Dear People of Assam,
# For Perspective
#
# Money spend on Modi's publicity - 4500 crores
# Money spent on ONLY Modi's securi…
# Created Date:- Fri Feb 07 11:38:25 +0000 2020
# -----
# name:- Avinash
# text:- @Sufshaikh @RRPSpeaks WHAT IS ADVANTAGE AND DISADVANTAGE OF CAA AND NRC.
# Created Date:- Fri Feb 07 11:38:20 +0000 2020
# -----
# name:- Unknown-نامعلوم
# text:- RT @SQMasood: Police taking down details of participants of a protest meet against #CAA_NRC_NPR at Barkas ground today. https://t.co/c3HbQ9…
# Created Date:- Fri Feb 07 11:38:16 +0000 2020
# -----
# name:- bitts sharma
# text:- RT @RAC7R: Journalists attacked at Shaheen Bagh for asking questions
#
# YouTuber attacked at Shaheen Bagh for recording video
#
# All this bcz t…
# Created Date:- Fri Feb 07 11:38:16 +0000 2020
# -----
# name:- @Jitendersoni9999 chowkidar
# text:- RT @Naveenk70993743: सूरत के कपड़ा व्यापारीयों द्वारा राष्ट्र हित मे एक कदम ।
# अपने पार्सल जो पूरे भारत मे जाते है उनकी पट्टी पर लिखा हम #CA…
# Created Date:- Fri Feb 07 11:38:14 +0000 2020
# -----
# name:- Patishapta
# text:- Mamata arrests leaders Kailash Vijavargiya and Mukul for supporting a peaceful CAA rally in Kolkata - Same Mamata w… https://t.co/ZJ4sXarr1Q
# Created Date:- Fri Feb 07 11:38:14 +0000 2020
# -----
# name:- PRAVEENKUMAR.R
# text:- RT @arivalayam: கழக தலைவர் @mkstalin அவர்கள், சென்னை வடக்கு மாவட்ட திமுக சார்பில், இராயபுரம் மேற்கு பகுதி - மீனாட்சியம்மன்பேட்டையில் நடைபெ…
# Created Date:- Fri Feb 07 11:38:13 +0000 2020
# -----
# name:- RKHuria
# text:- #AAPBJPekHai
#
# AAP-BJP have a common stand on:
#
# -Economy
# -Section 370
# -CAA/ NRC
# -Shaheen Bagh
#
# Both parties are communal
# Created Date:- Fri Feb 07 11:38:11 +0000 2020
# -----
# name:- 🇮🇳
# text:- RT @OpIndia_com: While Clown Kamra got banned after heckling Arnab mid-flight, Uber Driver in Mumbai takes a communist straight to police s…
# Created Date:- Fri Feb 07 11:38:10 +0000 2020
# -----
# name:- Warrior
# text:- @ArunnVashisth10 @Babaaagaya @NaanOfficialBC @RashmijoshiRJ @troooperOP @BombMaarDunga @Aniiiiish @scorprian… https://t.co/xkK0IgXcBi
# Created Date:- Fri Feb 07 11:38:10 +0000 2020
# -----
# name:- बिट्टु शेर्पा NRC+NPR+CIVIL_C के हिमायती💪✊👊
# text:- RT @Chirag_Sinh13: कल संसद में कहा और पहले भी बोल दिया है प्रधानमंत्री मोदी जी ने CAA से देश के किसी भी नागरिक को कुछ भी लेना देना नहीं है…
# Created Date:- Fri Feb 07 11:38:09 +0000 2020
# -----
# name:- Wajahat Jilani
# text:- RT @seemay: To a call from the Rector at Deoband's Dar ul Uloom, to put the protest on hold, a protestor, Shabana Qureshi reacts: "it is no…
# Created Date:- Fri Feb 07 11:38:08 +0000 2020
# -----
# name:- Ronak Sharma
# text:- @NO_CAA_NRC_NPR @kr5667 @rohitmishra183 @AritraRoy6 @ANI @Uber How do you infiltrate main road? Just because woh gh… https://t.co/AK5NrlgSTE
# Created Date:- Fri Feb 07 11:38:05 +0000 2020
# -----
# name:- Ved&dhruv
# text:- RT @Chirag_Sinh13: कल संसद में कहा और पहले भी बोल दिया है प्रधानमंत्री मोदी जी ने CAA से देश के किसी भी नागरिक को कुछ भी लेना देना नहीं है…
# Created Date:- Fri Feb 07 11:38:03 +0000 2020
# -----
# name:- WithRG
# text:- RT @chinmoyee5: No matter if the BJP MPs hide themselves in private tunnels,
#
# No matter they create NRC&amp;CAA clouds,
#
# No matter how dense th…
# Created Date:- Fri Feb 07 11:38:03 +0000 2020
# -----
# name:- Babu Ram Yadav
# text:- RT @nijunction: "I don't understand why the #ShaheenBaghProtest is still going on. There's no basis!"
#
# Agro engineer and national youth lea…
# Created Date:- Fri Feb 07 11:37:51 +0000 2020
# -----
# name:- Shaikh Adnan عدنان
# text:- Day 5
# My city Chota Shaheen bagh
#
# #ShaheenBagh #CAA_NRC_Protests https://t.co/gPB4NsQfOt
# Created Date:- Fri Feb 07 11:37:43 +0000 2020
# -----
# name:- Spiritual êncounter
# text:- #KejriwalTsunami
# बीजेपी जीती तो CAA,NPR,NRC पर मुहर।
# AAP जीती तो बिजली, पानी, स्वास्थ्य, शिक्षा, रोजगार पर मुहर।
# Created Date:- Fri Feb 07 11:37:36 +0000 2020
# -----
# name:- Sultan Sattani
# text:- World in noticing .@Uber! Have your .@Uber_India .@UberINSupport make amends! #CAA_NRC_Protests https://t.co/w56oFG8OJG
# Created Date:- Fri Feb 07 11:37:30 +0000 2020
# -----
# name:- Wasim
# text:- RT @Fatima_Z0hra: So called Mumbai Bagh Delegation created by men who decided to call off the protests without consulting women.
# Women reje…
# Created Date:- Fri Feb 07 11:37:29 +0000 2020
# -----
# name:- RANJIT ROUTRAY
# text:- RT @rajeshrana222: At #ShaheenBagh wen u ask the Jhadoo pocha bartan waalis
# Wht is #CAA - Hain?
# Wht is #NRC - Hain? NCR?
# Wht is NPR - Hain…
# Created Date:- Fri Feb 07 11:37:28 +0000 2020
# -----
# name:- कट्टर हिन्दू
# text:- RT @Naveenk70993743: सूरत के कपड़ा व्यापारीयों द्वारा राष्ट्र हित मे एक कदम ।
# अपने पार्सल जो पूरे भारत मे जाते है उनकी पट्टी पर लिखा हम #CA…
# Created Date:- Fri Feb 07 11:37:28 +0000 2020
# -----
# name:- Mohamed Aleemulla Shariff
# text:- RT @faizan0008: #MumbaiBagh
# Mumbai modern road
# Arabia hotel lane
# Mumbai central
# #mumbaiprotest
# #CAA_NRC_Protest
# @IndiasMuslims https:/…
# Created Date:- Fri Feb 07 11:37:27 +0000 2020
# -----
# name:- Alliance Against CAA , NRC & NPR Mumbai
# text:- CAA, NRC, NPR KE KHILAF #MahaMorcha
# #ChaloAzadMaidan
# #BharoAzadMaidan
# 15th Feb 2020 | 2 PM to 5 PM.
# #Mumbai… https://t.co/CjvCgdHPMM
# Created Date:- Fri Feb 07 11:37:27 +0000 2020
# -----
# name:- राजीव पटेल
# text:- @romanaisarkhan NOTA का बटन दबा के CAA का विरोध मुस्लिम कर सकते हैं ,इससे कम से कम ये संदेश जायेगा की इतने लोग CAA… https://t.co/D6gB7uBZLC
# Created Date:- Fri Feb 07 11:37:21 +0000 2020
# -----
# name:- Vinay Kushalappa 🇮🇳
# text:- @KodaguConnect #CAA
# #NRC
# Created Date:- Fri Feb 07 11:37:20 +0000 2020
# -----
# name:- Nur Shaikh
# text:- RT @_IndianMuslims: CAA: 'Protestors Forced Into Hiding, As UP Police Puts Bounty On Their Heads'
#
# "We have become a country where an alleg…
# Created Date:- Fri Feb 07 11:37:14 +0000 2020
# -----
# name:- Prakash R
# text:- RT @aloor_ShaNavas: மராட்டியரான @rajinikanth தமிழ்நாட்டிலிருந்து வெளியேற்றப்படும் நிலை வந்தால் முதலில் குரல் கொடுப்போம்!
# #Rajinikanth #NRC_…
# Created Date:- Fri Feb 07 11:37:13 +0000 2020
# -----
# name:- A M
# text:- RT @imMAK02: Very happy to see such kind of unity and communal harmony between different communities.
#
# Sanghis wanted to break this unity…
# Created Date:- Fri Feb 07 11:37:07 +0000 2020
# -----
# name:- NoCAA
# text:- RT @infomubashir: Now it’s become #TRS cadre vs @hydcitypolice at #MGBS Police didn’t allow even #TRS workers at MGBS. #NRC_CAA_NPR #Hydera…
# Created Date:- Fri Feb 07 11:37:04 +0000 2020
# -----
# name:- Dr.Tahir Zaidi
# text:- RT @MahtabNama: Reacting to #DarulUloomDeoband  Mohtamim's statement, #ShabanaQureshi, a protester at #ShaheenBagh told @thewire_in : "Ye m…
# Created Date:- Fri Feb 07 11:37:01 +0000 2020
# -----
# name:- salma
# text:- RT @imMAK02: Very happy to see such kind of unity and communal harmony between different communities.
#
# Sanghis wanted to break this unity…
# Created Date:- Fri Feb 07 11:36:58 +0000 2020
# -----
# name:- Razaul Haq Ansari
# text:- दारूल उलूम देवबंद ने शाहीनबाग में चल रहे CAA NRC NPR के खिलाफ प्रोटेस्ट को बंद करने की अपील की। https://t.co/7A52b6EJut
# Created Date:- Fri Feb 07 11:36:58 +0000 2020
# -----
# name:- अमन ठाकुर🌞⏺️
# text:- RT @OpIndia_in: बंद करो शाहीन बाग़ प्रदर्शन: ठंडे पड़े दारुल उलूम देवबंद के तेवर, विदेशी फंडिंग की खुल रही है पोल
#
# #Shaheenbagh
#
# https://…
# Created Date:- Fri Feb 07 11:36:57 +0000 2020
# -----
# name:- राजीव पटेल
# text:- NOTA का बटन दबा के CAA का विरोध मुस्लिम कर सकते हैं ,इससे कम से कम ये संदेश जायेगा की इतने लोग CAA के विरोध मे हैं… https://t.co/VXeUJxIg0H
# Created Date:- Fri Feb 07 11:36:56 +0000 2020
# -----
# name:- राणा केदार चन्देल
# text:- RT @OpIndia_in: इसी शाहीन बाग़ के घोषणा पत्र के आधार पर देश के कई जगहों से आपने यह भी सुना होगा कि अब विरोध CAA का है ही नहीं, बल्कि सरकार…
# Created Date:- Fri Feb 07 11:36:53 +0000 2020
# -----
# name:- yogesh yadav yogi
# text:- RT @SirManojYadav: नोटबन्दी एक राजनीतिक फैसला था, राज्यों के चुनाव जीतने के लिए जीडीपी में 2% की गिरावट किया करोड़ों लोगों को बेरोजगार भी…
# Created Date:- Fri Feb 07 11:36:51 +0000 2020
# -----
# name:- sk yasin ali
# text:- RT @MahtabNama: Reacting to #DarulUloomDeoband  Mohtamim's statement, #ShabanaQureshi, a protester at #ShaheenBagh told @thewire_in : "Ye m…
# Created Date:- Fri Feb 07 11:36:51 +0000 2020
# -----
# name:- Sagar Pareek
# text:- @rkarma214 @trailhead @salesforce @amandabauman @kavibdra @Bhanz19 @ManaswiPauskar @iKishorebt @technodhaba… https://t.co/0e0I36ppMV
# Created Date:- Fri Feb 07 12:06:13 +0000 2020
# -----
# name:- شاذاب
# text:- RT @seemay: To a call from the Rector at Deoband's Dar ul Uloom, to put the protest on hold, a protestor, Shabana Qureshi reacts: "it is no…
# Created Date:- Fri Feb 07 11:36:47 +0000 2020
# -----
# name:- கோவை கா.நாசர்® 🇮🇳
# text:- RT @nathgiri2: எங்க..அப்பன்..தாத்தன்ல்லாம்..
# எங்க பொறந்தாங்கன்னு ..ஏண்டா எங்க உயிரை வாங்குறீங்க?
#
# நீங்கதான்..ராமரு பொறந்த இடத்தையே.. கண்டு…
# Created Date:- Fri Feb 07 11:36:40 +0000 2020
# -----
# name:- Arun@runner
# text:- RT @ashokepandit: I salute the cab driver.
# Cab driver in Mumbai drives 'laal salam' communist straight to police station https://t.co/A7ue…
# Created Date:- Fri Feb 07 11:36:40 +0000 2020
# -----
# name:- Kabira Paresh
# text:- RT @salimdotcomrade: Worse than Emergency! #CAA_NRC https://t.co/p6S5lqHmaH
# Created Date:- Fri Feb 07 11:36:37 +0000 2020
# -----
# name:- Ami Assayag
# text:- RT @CRMScience: 🌠We're Hiring!🌠
# Apply to join our team as a #SalesforceDeveloper, Analyst, ESM, or #UX #Developer. We have flexible schedu…
# Created Date:- Fri Feb 07 12:06:54 +0000 2020
# -----
# name:- Kengo Iwata - Repro
# text:- RT @t14i_: 一方で、Salesforceゴリっといじれてるレベルのノンエンジニアの人はこれ手に入れると業務アプリくらいなら自分で作れるようになるはず。そういう人は向いてる。
#
# DBの複雑さ上がるとどうなるかはよくわかってないけど。
# Created Date:- Fri Feb 07 12:06:50 +0000 2020
# -----
# name:- Ami Assayag
# text:- RT @CRMScience: ☝️Choosing the right #Salesforce consultancy requires exploration into the types of solutions involved with a particular ch…
# Created Date:- Fri Feb 07 12:06:35 +0000 2020
# -----
# name:- Benjamin Galazzo
# text:- RT @Benioff: Together we will plant 1 Trillion Trees sequestering over 200 gigatons of carbon in 10 years. Salesforce will plant 100 Millio…
# Created Date:- Fri Feb 07 12:06:26 +0000 2020
# -----
# name:- Ami Assayag
# text:- RT @CRMScience: 🤷 So, you know your #Salesforce org needs work, but you're not sure where to start.... Read our client success stories to l…
# Created Date:- Fri Feb 07 12:06:21 +0000 2020
# -----
# name:- Ami Assayag
# text:- RT @CRMScience: Learn how to get "things" done in #Salesforce using process #automation and flows. You can access @kirkevonphilly's present…
# Created Date:- Fri Feb 07 12:06:02 +0000 2020
# -----
# name:- sfdcbot 🤖
# text:- RT @CRMScience: The #Salesforce Spring '20 Release includes exciting enhancements that were unveiled at #DF19. Here's a preview of our favo…
# Created Date:- Fri Feb 07 12:05:23 +0000 2020
# -----
# name:- Ami Assayag
# text:- RT @CRMScience: The #Salesforce Spring '20 Release includes exciting enhancements that were unveiled at #DF19. Here's a preview of our favo…
# Created Date:- Fri Feb 07 12:05:18 +0000 2020
# -----
# name:- Ami Assayag
# text:- RT @CRMScience: 🙌 Today is a special day at The Cube. We will celebrate the additions of @NickMcMuIIen and @tjk197 to the #Cubeforce team w…
# Created Date:- Fri Feb 07 12:05:14 +0000 2020
# -----
# name:- John Farrelly
# text:- RT @ManhattanEdu: What a night!
#
# $2.6 million was raised at tonight's De La Salle Medal Dinner, honoring Anthony Fernicola '78, '82MBA,  p…
# Created Date:- Fri Feb 07 12:04:23 +0000 2020
# -----
# name:- naoko tochibayashi
# text:- RT @Benioff: Together we will plant 1 Trillion Trees sequestering over 200 gigatons of carbon in 10 years. Salesforce will plant 100 Millio…
# Created Date:- Fri Feb 07 12:03:51 +0000 2020
# -----
# name:- Pranoti Vaidya
# text:- Woohoo!! Completed Developer superset  #FebruaryChallange #BeSuperQuest #trailheadquests #LearnedAlot
# @trailhead… https://t.co/bGuasqw3re
# Created Date:- Fri Feb 07 12:03:05 +0000 2020
# -----
# name:- Montu Jain
# text:- @ITConsultants4u @Contest_in @Contest_Hub @ITcontest @ITContest2013 @ContestsInIndia @Contestmumbai @ContestIndiaa… https://t.co/MMnwJT9F0k
# Created Date:- Fri Feb 07 12:02:03 +0000 2020
# -----
# name:- sfdcbot 🤖
# text:- RT @mason_frank: If you want to know how to build a great #Salesforce user group, ask the experts. So we did!
#
# Get the inside scoop from:…
# Created Date:- Fri Feb 07 12:01:38 +0000 2020
# -----
# name:- Global Employees
# text:- RT @mason_frank: If you want to know how to build a great #Salesforce user group, ask the experts. So we did!
#
# Get the inside scoop from:…
# Created Date:- Fri Feb 07 12:01:33 +0000 2020
# -----
# name:- ConvergeHub
# text:- Running a startup? Selling a product? You need to start tracking everything. Buy CRM from ConvergeHub: The ultimate… https://t.co/dBRkMxkEBw
# Created Date:- Fri Feb 07 12:01:09 +0000 2020
# -----
# name:- sfdcbot 🤖
# text:- RT @GoodDaySir_Army: Flip Flops and Tank Tops In this episode, we discuss IBM's cloud commercial, the Apple September 2015 Keynote event, a…
# Created Date:- Fri Feb 07 12:00:27 +0000 2020
# -----
# name:- GoodDay, Sir! Army
# text:- Flip Flops and Tank Tops In this episode, we discuss IBM's cloud commercial, the Apple September 2015 Keynote event… https://t.co/fVtmoM1T1f
# Created Date:- Fri Feb 07 12:00:21 +0000 2020
# -----
# name:- Robert Sösemann
# text:- @AidanHarding @we_are_nebula I found that there is no longer-lasting book wisdom out there regarding frontend. Ever… https://t.co/3rJx8uOXoh
# Created Date:- Fri Feb 07 12:00:08 +0000 2020
# -----
# name:- Mateen Greenway
# text:- Nonprofit Impact Measurement and the Sustainable Development Goals https://t.co/qcbP9wOWlh
# Created Date:- Fri Feb 07 12:00:01 +0000 2020
# -----
# name:- Sealand M. Flynn
# text:- If you are in hunting or farming sales, then this is worth a read and so is the eBook. Ian McAdam shares his top ti… https://t.co/PEQyS1y0Qt
# Created Date:- Fri Feb 07 12:00:01 +0000 2020
# -----
# name:- Samuel Chinedu
# text:- RT @_JobFather: Remote Job:- Senior Salesforce Developer - Citizenship - CORESPHERE LLC - Remote https://t.co/wLemrtnvfp #technology #javas…
# Created Date:- Fri Feb 07 11:59:46 +0000 2020
# -----
# name:- Samuel Chinedu
# text:- RT @basedremote: REMOTE JOB as Salesforce Software Engineering Intern at Calix https://t.co/6Xe0nGtoJo #remotejob https://t.co/uFcUli7StI
# Created Date:- Fri Feb 07 11:59:02 +0000 2020
# -----
# name:- Benjamin
# text:- Just earned the Project Management Plan Lite for Salesforce Partners badge on @Trailhead and you should too! https://t.co/iTMR6V0Ege
# Created Date:- Fri Feb 07 11:59:00 +0000 2020
# -----
# name:- sfdcbot 🤖
# text:- RT @rakeshsalesguru: #Sales #SalesforceBrings #Salesforce #SalesTips #salestraining #marketingstrategy #BusinessMan #BusinessGrowth #busine…
# Created Date:- Fri Feb 07 11:58:07 +0000 2020
# -----
# name:- Sales & Business Coach: Rakesh Sharma
# text:- #Sales #SalesforceBrings #Salesforce #SalesTips #salestraining #marketingstrategy #BusinessMan #BusinessGrowth… https://t.co/guWnPXBENB
# Created Date:- Fri Feb 07 11:58:01 +0000 2020
# -----
# name:- Motohashi Tsuyoshi
# text:- Salesforceの認定資格のリリース試験、年3回もあって頻度高いし、使ってない機能も出題されてけっこう難しいから大変ですよね。
# という話題で社内で盛り上がりました
# Created Date:- Fri Feb 07 11:57:53 +0000 2020
# -----
# name:- Chinna Rayudu
# text:- @ITConsultants4u @Contest_in @Contest_Hub @ITcontest @ITContest2013 @ContestsInIndia @Contestmumbai @ContestIndiaa… https://t.co/D3UXgfVVcS
# Created Date:- Fri Feb 07 11:57:51 +0000 2020
# -----
# name:- Amit Singh
# text:- Salesforce and Samsung invest in blockchain firm Digital Asset | ZDNet https://t.co/x7J5Qu2Djq #blockchain
# Created Date:- Fri Feb 07 11:56:34 +0000 2020
# -----
# name:- ☁️ Tom Blamire ☁️
# text:- RT @SalesforceAmy: #FridayThoughts
# #FridayFeeling https://t.co/HDzqS2Ztu0
# Created Date:- Fri Feb 07 11:55:41 +0000 2020
# -----
# name:- Courtney Hadden
# text:- RT @JodyKohner: ICYMI, a really thoughtful piece on the evolution of Corporate Sustainability by my friend and peer, @Flynnovate. Employees…
# Created Date:- Fri Feb 07 11:55:19 +0000 2020
# -----
# name:- 野﨑 智裕｜DreamArts カスタマーサクセス統括本部
# text:- SalesforceとGoogleスプレッドシートを連携させるアドオンのData connector for Salesforce、便利すぎる。最高。
# レコードの一括置換くらいは標準で簡単に出来てほしいなと思ってたけど、これなら私でも余裕。
# Created Date:- Fri Feb 07 11:55:13 +0000 2020
# -----
# name:- sfdcbot 🤖
# text:- RT @BspokeCommunity: Get branded, lightning-fast Salesforce Communities with the help of Bespoke Community.
# #salesforce #technology #symbol…
# Created Date:- Fri Feb 07 11:55:05 +0000 2020
# -----
# name:- Bespoke Community
# text:- Get branded, lightning-fast Salesforce Communities with the help of Bespoke Community.
# #salesforce #technology… https://t.co/bIMJkw28KT
# Created Date:- Fri Feb 07 11:55:00 +0000 2020
# -----
# name:- Bharti Singh
# text:- RT @shubham_sfdc: Thank you❤️
#
# @Salesforce_Geek @salesforce
# #salesforcegeek #salesforce
#
# Yt:-
# https://t.co/mfAWBTQPGx https://t.co/FDIxT8M3…
# Created Date:- Fri Feb 07 11:54:49 +0000 2020
# -----
# name:- Brian J. Grim
# text:- RT @suewarnke: A blessed day of planning with my beloved #Faithforce Global Leadership team at #Salesforce’s 2020 Global #Equality #Leaders…
# Created Date:- Fri Feb 07 11:54:38 +0000 2020
# -----
# name:- Ram Karma☁️
# text:- @shubham_sfdc @salesforce @Bhanz19 @asksalesforce Congratulations bro😍😍
# Created Date:- Fri Feb 07 11:54:27 +0000 2020
# -----
# name:- Ram Karma☁️
# text:- RT @shubham_sfdc: What a Lovely Surprise from @salesforce.
#
# Thank you so much for the love and support.
#
# Thank you @Bhanz19 Ma'am for the l…
# Created Date:- Fri Feb 07 11:54:08 +0000 2020
# -----
# name:- Smplicity
# text:- Our philosophy is to go even further, beyond expectations, transcending requirements to provide a more positive imp… https://t.co/V0cbOD9fE3
# Created Date:- Fri Feb 07 11:53:02 +0000 2020
# -----
# name:- Felix Böpple
# text:- Cloud Computing ist in der vergangen Dekade als DER bestimmende IT Trend durch die Decke gegangen. Aber wann und wi… https://t.co/dLKTTHtl8a
# Created Date:- Fri Feb 07 11:53:00 +0000 2020
# -----
# name:- Holandés errante
# text:- RT @carisimolider: "En esta iniciativa, Vocento cuenta con el respaldo d Banco Santander, Armani, Iberia, L’Oréal París, Novartis, Salesfor…
# Created Date:- Fri Feb 07 11:52:58 +0000 2020
# -----
# name:- Ｔｏｎｙ Ｓｍｉｔｈ ＡＣＩＨ                     #SocialHousing
# text:- RT @HousingITguy: In #SocialHousing,is ERP becoming the new HMS🤔
#
# Is SalesForce to change the #ukHousing game. A horse coming up on the ins…
# Created Date:- Fri Feb 07 11:50:29 +0000 2020
# -----
# name:- Ned James
# text:- It's not enough for you to have Salesforce, people have to use it and if you have t use a stick so be it. #salesforce #crm #selling
# Created Date:- Fri Feb 07 11:50:03 +0000 2020
# -----
# name:- Suresh Kalyan
# text:- RT @asksalesforce: Build yourself a mobile app page in the #newSalesforcemobileapp. Check out our blog to learn more: https://t.co/F3aYTaqW…
# Created Date:- Fri Feb 07 11:49:22 +0000 2020
# -----
# name:- K
# text:- RT @nori76: Adobeは時価総額が1780億ドル(約19兆円超)を超えて、Oracleを抜きソフトウェア会社としてMicrosoftに次ぐ二位に。
#
# Adobe and Salesforce overturn old order in cloud revolutio…
# Created Date:- Fri Feb 07 11:47:55 +0000 2020
# -----
# name:- K2 University
# text:- Want to get more involved in the #Salesforce community in #Frankfurt? Join the community meetup, where this time we… https://t.co/h9RqllkgNV
# Created Date:- Fri Feb 07 11:47:25 +0000 2020
# -----
# name:- Ram Karma☁️
# text:- @stratoflow @trailhead @salesforce @amandabauman @kavibdra @Bhanz19 @ManaswiPauskar @iKishorebt @technodhaba… https://t.co/6VyGvG9bR1
# Created Date:- Fri Feb 07 11:46:50 +0000 2020
# -----
# name:- Zarina Varley Scott (Zaz)
# text:- @FlorenceOnanuga @missylongshore @CherFeldman @ShirleneChow @trailhead @LeahBMH @swbjoyce @rockchick322004 Hey Flor… https://t.co/xR020cDtLY
# Created Date:- Fri Feb 07 11:46:49 +0000 2020
# -----
# name:- Tj
# text:- @gemziebeth Which car??? Tesla?
# Created Date:- Fri Feb 07 11:42:44 +0000 2020
