# %% [markdown]
# ## BFS & DFS

# %%
#input graph for bfs and dfs
graph = {'A' : ['B','C'], 'B' : ['D'], 'C' : ['E','F'],
'D' : [], 'E' : ['G'], 'F' : ['H','I'], 'H' : [],
'I' : [], 'G' : []}

# %%
#BFS
visited = []
queue = []
def bfs(visited, graph, node):
    visited.append(node)
    queue.append(node)
    while queue:
        s = queue.pop(0)
        print (s, end = " ")
        for neighbour in graph[s]:
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)

# %%
#DFS
visited1 =[] #set()
def dfs(graph,visited1,node):
    if node not in visited1:
        print(node,end=" ")
        visited1.append(node)
    for i in graph[node]:
        dfs(graph,visited1,i)

# %%
# Driver Code
print('INPUT TREE: ',graph)
print("BFS:")
bfs(visited, graph, 'A')
print("\nDFS:")
dfs(graph,visited1,'A')
# Out:
# INPUT TREE:  {'A': ['B', 'C'], 'B': ['D'], 'C': ['E', 'F'], 'D': [], 'E': ['G'], 'F': ['H', 'I'], 'H': [], 'I': [], 'G': []}
# BFS:
# A B C D E F G H I
# DFS:
# A B D C E G F H I

# %% [markdown]
# ## HILL_CLIMBING

# %%
import random
def randomSolution(tsp):
    cities = list(range(len(tsp)))
    solution = []
    for i in range(len(tsp)):
        randomCity = cities[random.randint(0, len(cities) - 1)]
        solution.append(randomCity)
        cities.remove(randomCity)
        
    return solution
def routeLength(tsp, solution):
    routeLength = 0
    for i in range(len(solution)):
        routeLength += tsp[solution[i - 1]][solution[i]]
        return routeLength
def getNeighbours(solution):
    neighbours = []
    for i in range(len(solution)):
        for j in range(i + 1, len(solution)):
            neighbour = solution.copy()
            neighbour[i] = solution[j]
            neighbour[j] = solution[i]
            neighbours.append(neighbour)
    return neighbours
def getBestNeighbour(tsp, neighbours):
    bestRouteLength = routeLength(tsp, neighbours[0])
    bestNeighbour = neighbours[0]
    for neighbour in neighbours:
        currentRouteLength = routeLength(tsp, neighbour)
        if currentRouteLength < bestRouteLength:
            bestRouteLength = currentRouteLength
            bestNeighbour = neighbour
    return bestNeighbour, bestRouteLength
def hillClimbing(tsp):
    currentSolution = randomSolution(tsp)
    currentRouteLength = routeLength(tsp, currentSolution)
    neighbours = getNeighbours(currentSolution)
    bestNeighbour, bestNeighbourRouteLength = getBestNeighbour(tsp, neighbours)
    while bestNeighbourRouteLength < currentRouteLength:
        currentSolution = bestNeighbour
        currentRouteLength = bestNeighbourRouteLength
        neighbours = getNeighbours(currentSolution)
        bestNeighbour, bestNeighbourRouteLength = getBestNeighbour(tsp,neighbours)
    return currentSolution, currentRouteLength
def main():
    tsp = [
        [0, 400, 500, 300],
        [400, 0, 300, 500],
        [500, 300, 0, 400],
        [300, 500, 400, 0]]
    print(hillClimbing(tsp))
if __name__ == "__main__":
    main()
# Out:
# ([1, 3, 0, 2], 300)

# %% [markdown]
# ## A*

# %%
def Astar(start, Goal):
    open_list = set(start)
    closed_list = set()
    g = {} #store distance from starting node
    parents = {}# parents contains an adjacency map of all nodes

    g[start] = 0
    parents[start] = start
    while len(open_list) > 0:
        n = None
        for v in open_list:
            if n == None or g[v] + heuristic(v) < g[n] + heuristic(n):
                n = v
        if n == Goal or Graph[n] == None:
            pass
        else:
            for (m, weight) in get_neighbors(n):
                if m not in open_list and m not in closed_list:
                    open_list.add(m)
                    parents[m] = n
                    g[m] = g[n] + weight
                else:
                    if g[m] > g[n] + weight:
                            g[m] = g[n] + weight
                            parents[m] = n
                            if m in closed_list:
                                closed_list.remove(m)
                                open_list.add(m)
                                
        if n == None:
            print('Path does not exist!')
            return None
        if n == Goal:
            path = []
            while parents[n] != n:
                path.append(n)
                n = parents[n]
            path.append(start)
            path.reverse()
            print('Path found: {}'.format(path))
            return path
            
        open_list.remove(n)
        closed_list.add(n)
            
    print('Path does not exist!')
    return None
def get_neighbors(v):
    if v in Graph:
        return Graph[v]
    else:
        return None
def heuristic(n):
    H_dist = {
        'A': 11,
        'B': 6,
        'C': 99,
        'D': 1,
        'E': 7,
        'G': 0,
    }
    return H_dist[n]
Graph = {
    'A': [('B', 2), ('E', 3)],
    'B': [('C', 1),('G', 9)],
    'C': None,
    'E': [('D', 6)],
    'D': [('G', 1)],
}
Astar('A', 'G')
# Out:
# Path found: ['A', 'E', 'D', 'G']
# ['A', 'E', 'D', 'G']

# %% [markdown]
# ## BFS

# %%
from queue import PriorityQueue
v = 14
graph = [[] for i in range(v)]
def best_first_search(source, target, n):
    visited = [0] * n
    visited[0] = True
    pq = PriorityQueue()
    while pq.empty() == False:
        u = pq.get()[1]
        print(u, end=" ")
        if u == target:
            break
        for v, c in graph[u]:
            if visited[v] == False:
                visited[v] = True
                pq.put((c, v))
    print()
def addedge(x, y, cost):
    graph[x].append((y, cost))
    graph[y].append((x, cost))
addedge(0, 1, 3)
addedge(0, 2, 6)
addedge(0, 3, 5)
addedge(1, 4, 9)
addedge(1, 5, 8)
addedge(2, 6, 12)
addedge(2, 7, 14)
addedge(3, 8, 7)
addedge(8, 9, 5)
addedge(8, 10, 6)
addedge(9, 11, 1)
addedge(9, 12, 10)
addedge(9, 13, 2)
source = 0
target = 9
best_first_search(source, target, v)

# %% [markdown]
# ## Alfa_beta_prunning

# %%
import numpy as np
def unitStep(v):
    if v >= 0:
        return 1
    else:
        return 0
def perceptronModel(x, w, b):
    v = np.dot(w, x) + b
    y = unitStep(v)
    return y
# w1 = 1, w2 = 1, b = -0.5
def OR_logicFunction(x):
    w = np.array([1, 1])
    b = -0.5
    return perceptronModel(x, w, b)
# testing the Perceptron Model 
test1 = np.array([0, 1])
test2 = np.array([1, 1])
test3 = np.array([0, 0])
test4 = np.array([1, 0])

print("OR({}, {}) = {}".format(0, 1, OR_logicFunction(test1)))
print("OR({}, {}) = {}".format(1, 1, OR_logicFunction(test2)))
print("OR({}, {}) = {}".format(0, 0, OR_logicFunction(test3)))
print("OR({}, {}) = {}".format(1, 0, OR_logicFunction(test4)))
# Out:
# OR(0, 1) = 1
# OR(1, 1) = 1
# OR(0, 0) = 0
# OR(1, 0) = 1

# %% [markdown]
# ## MIN_MAX_ALgorithm

# %%
MAX, MIN = 1000, -1000
def minimax(depth, nodeIndex, maximizingPlayer, values, alpha, beta):
    if depth == 3:
        return values[nodeIndex]
    if maximizingPlayer:
        best = MIN
        for i in range(0, 2):
            val = minimax(depth + 1, nodeIndex * 2 + i, False, values, alpha, beta)
            best = max(best, val)
            alpha = max(alpha, best)
            if beta <= alpha:
                break
        return best
    else:
        best = MAX
        for i in range(0, 2):
            val = minimax(depth + 1, nodeIndex * 2 + i, True, values, alpha, beta)
            best = min(best, val)
            beta = min(beta, best)
            if beta <= alpha:
                break
        return best
values = [3, 5, 6, 9, 1, 2, 0, -1]
print("The optimal value is :", minimax(0, 0, True, values, MIN, MAX))
# Out:
# The optimal value is : 5

# %% [markdown]
# ## Breath_First_search

# %%
from queue import PriorityQueue
v = 14
graph = [[] for i in range(v)]
# Function For Implementing Best First Search
# Gives output path having lowest cost
def best_first_search(source, target, n):
    visited = [0] * n
    visited[0] = True
    pq = PriorityQueue()
    pq.put((0, source))
    while pq.empty() == False:
        u = pq.get()[1]
        # Displaying the path having lowest cost
        print(u, end=" ")
        if u == target:
                break
        for v, c in graph[u]:
            if visited[v] == False:
                visited[v] = True
                pq.put((c, v))
    print()
    # Function for adding edges to graph
def addedge(x, y, cost):
        graph[x].append((y, cost))
        graph[y].append((x, cost))
 
# The nodes shown in above example(by alphabets) are
# implemented using integers addedge(x,y,cost);
addedge(0, 1, 3)
addedge(0, 2, 6)
addedge(0, 3, 5)
addedge(1, 4, 9)
addedge(1, 5, 8)
addedge(2, 6, 12)
addedge(2, 7, 14)
addedge(3, 8, 7)
addedge(8, 9, 5)
addedge(8, 10, 6)
addedge(9, 11, 1)
addedge(9, 12, 10)
addedge(9, 13, 2)
source = 0
target = 9
best_first_search(source, target, v)
# Out:
# 0 1 3 2 8 9

# %% [markdown]
# ## Genetic_ALgorithm

# %%
import random 
  
# Number of individuals in each generation 
POPULATION_SIZE = 100
  
# Valid genes 
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP 
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''
  
# Target string to be generated 
TARGET = "CS mean Common Sense "
  
class Individual: 

    def __init__(self, chromosome): 
        self.chromosome = chromosome  
        self.fitness = self.cal_fitness() 
  
    @classmethod
    def mutated_genes(self): 
        global GENES 
        return random.choice(GENES)  
  
    @classmethod
    def create_gnome(self): 
        global TARGET
        return [self.mutated_genes() for _ in range(len(TARGET))] 
  
    def mate(self, par2): 
  
        child_chromosome = [] 
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):     
  
            prob = random.random() 

            if prob < 0.45: 
                child_chromosome.append(gp1) 

            elif prob < 0.90: 
                child_chromosome.append(gp2) 
  
            else: 
                child_chromosome.append(self.mutated_genes()) 
  
        return Individual(child_chromosome) 
  
    def cal_fitness(self): 
        global TARGET 
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET): 
            if gs != gt: fitness+= 1
        return fitness 
  

def main(): 
    global POPULATION_SIZE 
    generation = 1
    found = False
    population = [] 
    for _ in range(POPULATION_SIZE): 
        gnome = Individual.create_gnome() 
        population.append(Individual(gnome)) 
    while not found: 
        population = sorted(population, key = lambda x:x.fitness) 
        if population[0].fitness <= 0: 
            found = True
            break
  
        new_generation = [] 
  
        s = int((10*POPULATION_SIZE)/100) 
        new_generation.extend(population[:s]) 
  
      
        s = int((90*POPULATION_SIZE)/100) 
        for _ in range(s): 
            parent1 = random.choice(population[:50]) 
            parent2 = random.choice(population[:50]) 
            child = parent1.mate(parent2) 
            new_generation.append(child) 
  
        population = new_generation 
        print("Generation: "+format(generation))
        print("String: "+"".join(population[0].chromosome))
        print("Fitness: "+format(population[0].fitness))
  
        generation += 1
  
    print("Generation: "+format(generation))
    print("String: "+"".join(population[0].chromosome))
    print("Fitness: "+format(population[0].fitness))  

if __name__ == '__main__': 
    main()
# Out:
# Generation: 1
# String: DCckp}1 e)o{t% y"XCp
# Fitness: 18
# Generation: 2
# String: DCckp}1 e)o{t% y"XCp
# Fitness: 18
# Generation: 3
# String: DCckp}1 e)o{t% y"XCp
# Fitness: 18
# Generation: 4
# String: D-Xr9}- :)eRoh j"I#p
# Fitness: 17
# Generation: 5
# String: D-Xr9}- :)eRoh j"I#p
# Fitness: 17
# Generation: 6
# String: CZ B9_@ .cm[E=}-:nAPT
# Fitness: 16
# Generation: 7
# String: CZ B9_@ .cm[E=}-:nAPT
# Fitness: 16
# Generation: 8
# String: Dk []hx tlm1qn BT fe
# Fitness: 14
# Generation: 9
# String: C- K9GG ./mc!_ -:nsw
# Fitness: 13
# Generation: 10
# String: C- K9GG ./mc!_ -:nsw
# Fitness: 13
# Generation: 11
# String: d[ --3x tlmSon BT se
# Fitness: 12
# Generation: 12
# String: d[ --3x tlmSon BT se
# Fitness: 12
# Generation: 13
# String: d[ --3x tlmSon BT se
# Fitness: 12
# Generation: 14
# String: C- :iIJ ClmbhN kgnse
# Fitness: 11
# Generation: 15
# String: C- :iIJ ClmbhN kgnse
# Fitness: 11
# Generation: 16
# String: CC !5cA Cdmbo= VUnse
# Fitness: 10
# Generation: 17
# String: CC !5cA Cdmbo= VUnse
# Fitness: 10
# Generation: 18
# String: CC !5cA Cdmbo= VUnse
# Fitness: 10
# Generation: 19
# String: CS !-DxDCDmIon O,nse
# Fitness: 9
# Generation: 20
# String: CS !-DxDCDmIon O,nse
# Fitness: 9
# Generation: 21
# String: CS !-DxDCDmIon O,nse
# Fitness: 9
# Generation: 22
# String: CS !-DxDCDmIon O,nse
# Fitness: 9
# Generation: 23
# String: CS !-DxDCDmIon O,nse
# Fitness: 9
# Generation: 24
# String: CS !-DxDCDmIon O,nse
# Fitness: 9
# Generation: 25
# String: C- Iian Clm%on M
# nee
# Fitness: 8
# Generation: 26
# String: 9S l3an Clm=on OXnse
# Fitness: 7
# Generation: 27
# String: 9S l3an Clm=on OXnse
# Fitness: 7
# Generation: 28
# String: 9S l3an Clm=on OXnse
# Fitness: 7
# Generation: 29
# String: CS x-aD Clm=on S3nse
# Fitness: 6
# Generation: 30
# String: CS x-aD Clm=on S3nse
# Fitness: 6
# Generation: 31
# String: CS x-aD Clm=on S3nse
# Fitness: 6
# Generation: 32
# String: CS x-aD Clm=on S3nse
# Fitness: 6
# Generation: 33
# String: CS x-aD Clm=on S3nse
# Fitness: 6
# Generation: 34
# String: CS x-aD Clm=on S3nse
# Fitness: 6
# Generation: 35
# String: CS x-aD Clm=on S3nse
# Fitness: 6
# Generation: 36
# String: CS x-aD Clm=on S3nse
# Fitness: 6
# Generation: 37
# String: CS x-aD Clm=on S3nse
# Fitness: 6
# Generation: 38
# String: CS x-aD Clm=on S3nse
# Fitness: 6
# Generation: 39
# String: CS TeaK C m=on SXnse
# Fitness: 5
# Generation: 40
# String: CS TeaK C m=on SXnse
# Fitness: 5
# Generation: 41
# String: CS TeaK C m=on SXnse
# Fitness: 5
# Generation: 42
# String: CS TeaK C m=on SXnse
# Fitness: 5
# Generation: 43
# String: CS TeaK C m=on SXnse
# Fitness: 5
# Generation: 44
# String: CS TeaK C m=on SXnse
# Fitness: 5
# Generation: 45
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 46
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 47
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 48
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 49
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 50
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 51
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 52
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 53
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 54
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 55
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 56
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 57
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 58
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 59
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 60
# String: CS Tean Clm0on Smnse
# Fitness: 4
# Generation: 61
# String: CS Tean Cummon Snnse
# Fitness: 3
# Generation: 62
# String: CS Tean Cummon Snnse
# Fitness: 3
# Generation: 63
# String: CS Tean Cummon Snnse
# Fitness: 3
# Generation: 64
# String: CS Tean Cummon Snnse
# Fitness: 3
# Generation: 65
# String: CS Tean Cummon Snnse
# Fitness: 3
# Generation: 66
# String: CS Tean Cummon Snnse
# Fitness: 3
# Generation: 67
# String: CS Tean Cummon Snnse
# Fitness: 3
# Generation: 68
# String: CS Tean Cummon Snnse
# Fitness: 3
# Generation: 69
# String: CS Tean Cummon Snnse
# Fitness: 3
# Generation: 70
# String: CS Tean Cummon Snnse
# Fitness: 3
# Generation: 71
# String: CS Tean Cummon Snnse
# Fitness: 3
# Generation: 72
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 73
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 74
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 75
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 76
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 77
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 78
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 79
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 80
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 81
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 82
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 83
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 84
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 85
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 86
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 87
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 88
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 89
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 90
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 91
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 92
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 93
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 94
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 95
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 96
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 97
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 98
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 99
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 100
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 101
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 102
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 103
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 104
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 105
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 106
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 107
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 108
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 109
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 110
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 111
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 112
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 113
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 114
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 115
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 116
# String: CS Iean Clmmon Sense
# Fitness: 2
# Generation: 117
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 118
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 119
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 120
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 121
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 122
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 123
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 124
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 125
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 126
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 127
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 128
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 129
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 130
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 131
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 132
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 133
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 134
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 135
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 136
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 137
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 138
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 139
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 140
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 141
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 142
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 143
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 144
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 145
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 146
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 147
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 148
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 149
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 150
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 151
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 152
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 153
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 154
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 155
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 156
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 157
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 158
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 159
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 160
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 161
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 162
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 163
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 164
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 165
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 166
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 167
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 168
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 169
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 170
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 171
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 172
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 173
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 174
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 175
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 176
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 177
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 178
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 179
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 180
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 181
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 182
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 183
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 184
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 185
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 186
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 187
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 188
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 189
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 190
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 191
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 192
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 193
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 194
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 195
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 196
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 197
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 198
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 199
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 200
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 201
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 202
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 203
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 204
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 205
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 206
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 207
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 208
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 209
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 210
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 211
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 212
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 213
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 214
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 215
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 216
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 217
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 218
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 219
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 220
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 221
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 222
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 223
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 224
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 225
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 226
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 227
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 228
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 229
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 230
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 231
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 232
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 233
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 234
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 235
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 236
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 237
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 238
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 239
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 240
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 241
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 242
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 243
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 244
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 245
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 246
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 247
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 248
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 249
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 250
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 251
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 252
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 253
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 254
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 255
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 256
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 257
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 258
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 259
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 260
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 261
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 262
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 263
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 264
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 265
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 266
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 267
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 268
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 269
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 270
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 271
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 272
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 273
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 274
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 275
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 276
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 277
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 278
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 279
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 280
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 281
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 282
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 283
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 284
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 285
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 286
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 287
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 288
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 289
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 290
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 291
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 292
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 293
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 294
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 295
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 296
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 297
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 298
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 299
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 300
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 301
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 302
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 303
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 304
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 305
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 306
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 307
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 308
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 309
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 310
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 311
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 312
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 313
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 314
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 315
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 316
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 317
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 318
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 319
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 320
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 321
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 322
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 323
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 324
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 325
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 326
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 327
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 328
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 329
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 330
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 331
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 332
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 333
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 334
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 335
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 336
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 337
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 338
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 339
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 340
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 341
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 342
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 343
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 344
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 345
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 346
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 347
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 348
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 349
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 350
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 351
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 352
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 353
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 354
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 355
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 356
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 357
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 358
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 359
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 360
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 361
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 362
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 363
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 364
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 365
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 366
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 367
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 368
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 369
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 370
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 371
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 372
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 373
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 374
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 375
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 376
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 377
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 378
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 379
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 380
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 381
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 382
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 383
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 384
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 385
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 386
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 387
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 388
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 389
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 390
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 391
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 392
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 393
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 394
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 395
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 396
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 397
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 398
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 399
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 400
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 401
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 402
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 403
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 404
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 405
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 406
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 407
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 408
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 409
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 410
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 411
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 412
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 413
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 414
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 415
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 416
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 417
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 418
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 419
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 420
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 421
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 422
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 423
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 424
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 425
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 426
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 427
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 428
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 429
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 430
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 431
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 432
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 433
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 434
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 435
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 436
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 437
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 438
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 439
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 440
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 441
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 442
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 443
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 444
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 445
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 446
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 447
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 448
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 449
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 450
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 451
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 452
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 453
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 454
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 455
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 456
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 457
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 458
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 459
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 460
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 461
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 462
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 463
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 464
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 465
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 466
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 467
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 468
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 469
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 470
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 471
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 472
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 473
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 474
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 475
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 476
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 477
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 478
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 479
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 480
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 481
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 482
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 483
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 484
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 485
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 486
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 487
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 488
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 489
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 490
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 491
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 492
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 493
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 494
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 495
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 496
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 497
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 498
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 499
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 500
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 501
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 502
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 503
# String: CS mean Clmmon Sense
# Fitness: 1
# Generation: 504
# String: CS mean Common Sense
# Fitness: 0

# %% [markdown]
# ## Genetic Algorithms

# %%
import random
import datetime

geneSet = " abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!."
target = "SHASHIKUMAR"

   


def generate_parent(length):
    genes = []
    while len(genes) < length:
        sampleSize = min(length - len(genes), len(geneSet))
        genes.extend(random.sample(geneSet, sampleSize))
    return ''.join(genes)
 
def get_fitness(guess):
    return sum(1 for expected, actual in zip(target, guess)
               if expected == actual)
 
def mutate(parent):
    index = random.randrange(0, len(parent))
    childGenes = list(parent)
    newGene, alternate = random.sample(geneSet, 2)
    childGenes[index] = alternate  \
        if newGene == childGenes[index]  \
        else newGene
    return ''.join(childGenes)
 

def display(guess):
    timeDiff = datetime.datetime.now() - startTime
    fitness = get_fitness(guess)
    print("{0}\t{1}\t{2}".format(guess, fitness, str(timeDiff)))

random.seed()
startTime = datetime.datetime.now()
bestParent = generate_parent(len(target))
bestFitness = get_fitness(bestParent)
display(bestParent)

while True:
    child = mutate(bestParent)
    childFitness = get_fitness(child)

    if bestFitness >= childFitness:
        continue
    display(child)
    if childFitness >= len(bestParent):
        break
    bestFitness = childFitness
    bestParent = child
# Out:
# REUmyC qlxH	0	0:00:00
# REAmyC qlxH	1	0:00:00.001001
# REAmyC qlxR	2	0:00:00.001001
# RHAmyC qlxR	3	0:00:00.002002
# SHAmyC qlxR	4	0:00:00.007005
# SHAmyC qMxR	5	0:00:00.008005
# SHAmyC UMxR	6	0:00:00.011007
# SHAmyI UMxR	7	0:00:00.012008
# SHAmyIKUMxR	8	0:00:00.016011
# SHASyIKUMxR	9	0:00:00.018012
# SHASyIKUMAR	10	0:00:00.020014
# SHASHIKUMAR	11	0:00:00.035025
