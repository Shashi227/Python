# %% [markdown]
# # Seaborn

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
np.random.seed(sum(map(ord,"aesthetics")))
def sinplot(flip=1):
    x=np.linspace(0,14,100)
    for i in range(1,7):
        plt.plot(x,np.sin(x+i*0.5)*(7-i)*flip)
        
sns.set()
fig=plt.figure()
sinplot(1)

# %%
sns.set_style("whitegrid")
data=np.random.normal(size=(20,6))+np.arange(6)/2
sns.boxplot(data=data)

# %%
fig=plt.figure()
sns.set_style("darkgrid")
sinplot()

# %%
fig=plt.figure()
sns.set_style("white")
sinplot()

# %%
fig=plt.figure()
sns.set_style("ticks")
sinplot()

# %%
sinplot()
sns.despine()

# %%
plt.close('all')
f,ax=plt.subplots()
sns.violinplot(data=data)
sns.despine(offset=10,trim=True)
# Out:
# C:\Users\shashi kumar\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig=plt.figure()
sns.set_style("whitegrid")
sns.boxplot(data=data,palette="deep")
sns.despine(left=True)

# %%
import seaborn as sns
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': 'black',
#  'axes.grid': False,
#  'axes.axisbelow': 'line',
#  'axes.labelcolor': 'black',
#  'figure.facecolor': 'white',
#  'grid.color': '#b0b0b0',
#  'grid.linestyle': '-',
#  'text.color': 'black',
#  'xtick.color': 'black',
#  'ytick.color': 'black',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'projecting',
#  'patch.edgecolor': 'black',
#  'image.cmap': 'viridis',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['DejaVu Sans',
#   'Bitstream Vera Sans',
#   'Computer Modern Sans Serif',
#   'Lucida Grande',
#   'Verdana',
#   'Geneva',
#   'Lucid',
#   'Arial',
#   'Helvetica',
#   'Avant Garde',
#   'sans-serif'],
#  'patch.force_edgecolor': False,
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
fig = plt.figure()
with sns.axes_style("darkgrid"):
    plt.subplot(211)
    sinplot()
plt.subplot(212)
sinplot(-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-7138d7b2d558> in <module>
#       6 with sns.axes_style("darkgrid"):
#       7     plt.subplot(211)
# ----> 8     sinplot()
#       9 plt.subplot(212)
#      10 sinplot(-1)
#
# NameError: name 'sinplot' is not defined

# %%
sinplot()
sns.despine()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-0fffc092769e> in <module>
# ----> 1 sinplot()
#       2 sns.despine()
#
# NameError: name 'sinplot' is not defined

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(sum(map(ord,"aesthetics")))
def sinplot(flip=1):
    x=np.linspace(0,14,100)
    for i in range(1,7):
        plt.plot(x,np.sin(x+i*0.5)*(7-i)*flip)
        
sns.set()
fig=plt.figure()
sinplot(1)

# %%
fig = plt.figure()
with sns.axes_style("darkgrid"):
    plt.subplot(211)
    sinplot()
plt.subplot(212)
sinplot(-1)

# %%
fig=plt.figure()
sns.set_style("darkgrid",{"axes.facecolor":"0.9"})
sinplot()

# %%
fig=plt.figure()
sns.set_style("darkgrid",{"axes.facecolor":"0.1"})
sinplot()

# %%
import seaborn as sns
sns.set_context("notebook")
sinplot()

# %%
sns.set()

# %%
import seaborn as sns
sns.set_context("talk")
sinplot()

# %%
import seaborn as sns
sns.set_context("poster")
sinplot()

# %%
sns.set_context("notebook",font_scale=1.5,rc={"lines_linewidth":2.5})
sinplot()

# %%
print("19-01-2020")
# Out:
# 19-01-2020

# %%
current_palette=sns.color_palette()
sns.palplot(current_palette)

# %%
sns.palplot(sns.color_palette("hls",8))

# %%
sns.palplot(sns.hls_palette(8,l=.3,s=.8))

# %%
plt.plot([0,1],[0,1],sns.xkcd_rgb["pale red"],lw=3)
plt.plot([0,1],[0,2],sns.xkcd_rgb["medium green"],lw=3)
plt.plot([0,1],[0,3],sns.xkcd_rgb["denim blue"],lw=3)

# %%
colors=["windows blue","amber","greyish","faded green","dusty purple"]
sns.palplot(sns.xkcd_palette(colors))

# %%
sns.choose_colorbrewer_palette(data_type="sequential")
# Out:
# interactive(children=(Dropdown(description='name', options=('Greys', 'Reds', 'Greens', 'Blues', 'Oranges', 'Pu…
# [(0.9575547866205305, 0.9575547866205305, 0.9575547866205305),
#  (0.9012072279892349, 0.9012072279892349, 0.9012072279892349),
#  (0.8328950403690888, 0.8328950403690888, 0.8328950403690888),
#  (0.7502191464821223, 0.7502191464821223, 0.7502191464821223),
#  (0.6434140715109573, 0.6434140715109573, 0.6434140715109573),
#  (0.5387158785082661, 0.5387158785082661, 0.5387158785082661),
#  (0.440322952710496, 0.440322952710496, 0.440322952710496),
#  (0.342883506343714, 0.342883506343714, 0.342883506343714),
#  (0.22329873125720878, 0.22329873125720878, 0.22329873125720878),
#  (0.10469819300269129, 0.10469819300269129, 0.10469819300269129)]

# %%
sns.palplot(sns.color_palette("Blues"))
sns.palplot(sns.color_palette("BuGn_r"))
sns.palplot(sns.color_palette("GnBu_d"))

# %%
sns.palplot(sns.color_palette("RdBu_r",7))
sns.palplot(sns.color_palette("BuGn_r",7))
sns.palplot(sns.color_palette("coolwarm",7))

# %%
from scipy import stats, integrate
sns.set(color_codes=True)
np.random.seed(sum(map(ord,"distributions")))
x=np.random.normal(size=100)
sns.distplot(x);
# Out:
# C:\Users\shashi kumar\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(x,kde=False,rug=True)

# %%
sns.distplot(x,bins=20,kde=False,rug=True)

# %%
sns.distplot(x,hist=False,rug=True)

# %%
sns.kdeplot(x,shade=True)

# %%
sns.kdeplot(x)

# %%
sns.kdeplot(x,bw=.2,label="bw:0.2")
sns.kdeplot(x,bw=2,label="bw:2")

# %%
sns.kdeplot(x,shade=True,cut=0)
sns.rugplot(x)

# %%
x=np.random.gamma(6,size=200)
sns.distplot(x,kde=False,fit=stats.gamma)

# %%
np.random.seed(0)
x=np.random.randn(100)
ax=sns.distplot(x,vertical=True)

# %%
import pandas as pd
plt.close('all')
mean,cov=[0,1],[(1,.5),(.5,1)]
data=np.random.multivariate_normal(mean,cov,200)
df=pd.DataFrame(data,columns=["x","y"])
sns.jointplot(x="x",y="y",data=df)

# %%
x,y=np.random.multivariate_normal(mean,cov,100).T
with sns.axes_style("white"):
    sns.jointplot(x=x,y=y,kind="hex",color="k")

# %%
sns.jointplot(x="x",y="y",data=df,kind="kde")

# %%
f,ax = plt.subplots(figsize=(6,6))
sns.kdeplot(df.x,df.y,ax=ax)
sns.rugplot(df.x,color="g",ax=ax)
sns.rugplot(df.y,vertical=True,ax=ax)

# %%
g=sns.jointplot(x="x",y="y",data=df,kind="kde",color="m")
g.plot_joint(plt.scatter,c="w",s=30,linewidth=1,marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$x$","$y$")

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris);

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot,cmap="Blues_d",n_levels=6);
# Out:
# C:\Users\shashi kumar\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig=plt.figure()
sns.set(style="whitegrid",color_codes=True)
np.random.seed(sum(map(ord,"categorical")))
tips=sns.load_dataset("tips")
tips = sns.load_dataset("tips")
tips.head()
iris=sns.load_dataset("iris")
titanic = sns.load_dataset("titanic")
sns.stripplot(x="day",y="total_bill",data=tips);
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True);
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook
sns.stripplot?
sns.swarmplot(x="day",y="total_bill",hue="sex",data=tips)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.swarmplot(x="day",y="total_bill",data=tips)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.boxplot(x="day",y="total_bill",hue="time",data=tips)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.boxplot(x="day",y="total_bill",hue="time",data=tips)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.violinplot(x="total_bill",y="day",hue="time",data=tips)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.violinplot(x="total_bill",y="day",hue="time",data=tips,bw=.1,scale="count",scale_hue=False)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.violinplot(x="day",y="total_bill",hue="sex",data=tips,split=True)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.violinplot(x="day",y="total_bill",hue="sex",data=tips,split=True,inner="stick",palette="Set3")
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.violinplot(x="day",y="total_bill",hue="sex",data=tips,inner=None)
sns.violinplot(x="day",y="total_bill",hue="sex",data=tips,color="w",alpha=.5)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.violinplot(x="day",y="total_bill",hue="sex",data=tips,color="w",alpha=.5)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.barplot(x="sex",y="survived",hue="class",data=titanic)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.countplot(x="deck",data=titanic,palette="Greens_d")
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.pointplot(x="class",y="survived",hue="sex",data=titanic,palette={"male":"g","female":"m"},markers=["^","o"],linestyles=["-","--"])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.boxplot(data=iris,orient="h")
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig=plt.figure()
sns.factorplot(x="day",y="total_bill",hue="smoker",data=tips)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# C:\Users\shashi kumar\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# <img src="data:image/png;base64,..." width="522.222236056387">

# %%
fig=plt.figure()
sns.factorplot(x="time",y="total_bill",hue="smoker",col="day",data=tips,kind="box",size=4,aspect=.5)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# C:\Users\shashi kumar\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\shashi kumar\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="792.2222432089446">

# %%
sns.set(color_codes=True)
np.random.seed(sum(map(ord,"regression")))
tips=sns.load_dataset("tips")

# %%
fig=plt.figure()
sns.regplot(x="total_bill",y="tip",data=tips)
# Out:
# C:\Users\shashi kumar\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x="total_bill",y="tip",data=tips)

# %%
fig=plt.figure()
sns.lmplot(x="size",y="tip",data=tips)

# %%
fig=plt.figure()
sns.lmplot(x="size",y="tip",data=tips,x_jitter=.05)

# %%
sns.lmplot(x="size",y="tip",data=tips,x_estimator=np.mean)

# %%
anscombe=sns.load_dataset("anscombe")
sns.lmplot(x="x",y="y",data=anscombe.query("dataset=='I'"),ci=None,scatter_kws={"s":80});

# %%
fig=plt.figure()
sns.lmplot(x="x",y="y",data=anscombe.query("dataset=='II'"),ci=None,scatter_kws={"s":80});

# %%
fig=plt.figure()
sns.lmplot(x="x",y="y",data=anscombe.query("dataset=='II'"),order=2,ci=None,scatter_kws={"s":80});

# %%
fig=plt.figure()
tips["big_tip"]=(tips.tip / tips.total_bill) >.15
sns.lmplot(x="total_bill",y="big_tip",data=tips,y_jitter=0.3);

# %%
fig=plt.figure()
tips["big_tip"]=(tips.tip / tips.total_bill) >.15
sns.lmplot(x="total_bill",y="big_tip",data=tips,logistic=True,y_jitter=0.3);

# %%
fig=plt.figure()
sns.residplot(x="x",y="y",data=anscombe.query("dataset=='I'"))

# %%
fig=plt.figure()
sns.residplot(x="x",y="y",data=anscombe.query("dataset=='II'"))

# %%
sns.lmplot(x="x",y="y",data=anscombe.query("dataset=='III'"),ci=None,scatter_kws={"s":80});

# %%
sns.lmplot(x="x",y="y",data=anscombe.query("dataset=='III'"),robust=True,ci=None,scatter_kws={"s":80});

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",data=tips)

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",data=tips,markers=["o","x"],palette="Set1")

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",col="time",data=tips)

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",col="time",row="sex",data=tips)

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="reg")
